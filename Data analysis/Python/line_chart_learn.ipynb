# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/Users/yinhaiyi/Documents/数据库/营商环境/2021年_not_GE_1_vs_not_SE_1.csv")

# %%
x1 = df['低水平政务环境']
y1 = df['低水平战略新兴产业发展']

fig, ax = plt.subplots(figsize=(5, 5))  

# 散点图与对角线
ax.scatter(x1, y1, color='black', alpha=0.7)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(1.2)
ax.spines['left'].set_linewidth(1.2)
ax.grid(False)

ax.set_xlim(-0.05, 1.05)
ax.set_ylim(-0.05, 1.05)

plt.tight_layout()
plt.show()

# %%
x1 = df['高水平法治环境']
y1 = df['高水平战略新兴产业发展1']

fig, ax = plt.subplots(figsize=(5, 5))  

# 散点图与对角线
ax.scatter(x1, y1, color='black', alpha=0.7)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(1.2)
ax.spines['left'].set_linewidth(1.2)
ax.grid(False)

ax.set_xlim(-0.05, 1.05)
ax.set_ylim(-0.05, 1.05)

plt.tight_layout()
plt.show()

# %%
x1 = df['高水平政务环境']
y1 = df['高水平战略新兴产业发展2']

fig, ax = plt.subplots(figsize=(5, 5))  

# 散点图与对角线
ax.scatter(x1, y1, color='black', alpha=0.7)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(1.2)
ax.spines['left'].set_linewidth(1.2)
ax.grid(False)

ax.set_xlim(-0.05, 1.05)
ax.set_ylim(-0.05, 1.05)

plt.tight_layout()
plt.show()
